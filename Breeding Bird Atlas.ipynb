# %% [markdown]
# Part 1 - Data Analysis & Preprocessing

# %%
import pandas as pd # type: ignore
import numpy as np # type: ignore 
import matplotlib.pyplot as plt # type: ignore
import warnings
import seaborn as sns # type: ignore
import math

from LogisticRegression import LogitRegression

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('noisy_datasets/breeding_bird_atlas.csv')

# %%
print("Dataset shape",df.shape)
# Out:
# Dataset shape (361582, 16)

# %%
df.head(15)
# Out:
#     Fed. Region Block ID                                           Map Link  \
# 0           NaN    5773C                                                 50
# 1           8.0    5569B  http://www.dec.ny.gov/data/dfwmr/bba/pdf/5569b...
# 2           8.0    5773C  http://www.dec.ny.gov/data/dfwmr/bba/pdf/5773c...
# 3           8.0    5872A  http://www.dec.ny.gov/data/dfwmr/bba/pdf/5872a...
# 4           8.0    5570D  http://www.dec.ny.gov/data/dfwmr/bba/pdf/5570d...
# 5           8.0    5671D  http://www.dec.ny.gov/data/dfwmr/bba/pdf/5671d...
# 6           8.0    5669A  http://www.dec.ny.gov/data/dfwmr/bba/pdf/5669a...
# 7           8.0    5872C  http://www.dec.ny.gov/data/dfwmr/bba/pdf/5872c...
# 8           8.0    5870D  http://www.dec.ny.gov/data/dfwmr/bba/pdf/5870d...
# 9           8.0    5871B  http://www.dec.ny.gov/data/dfwmr/bba/pdf/5871b...
# 10          8.0    5569B  http://www.dec.ny.gov/data/dfwmr/bba/pdf/5569b...
# 11          8.0    5872D  http://www.dec.ny.gov/data/dfwmr/bba/pdf/5872d...
# 12          8.0    5973D  http://www.dec.ny.gov/data/dfwmr/bba/pdf/5973d...
# 13          8.0    5872C  http://www.dec.ny.gov/data/dfwmr/bba/pdf/5872c...
# 14          8.0    5669A  http://www.dec.ny.gov/data/dfwmr/bba/pdf/5669a...
#
#     County          Common Name        Scientific Name NYS Protection Status  \
# 0      NaN                  NaN                     12                    10
# 1   ALBANY     Alder Flycatcher      Empidonax alnorum             Protected
# 2   ALBANY  American Black Duck          Anas rubripes          Game Species
# 3   ALBANY  American Black Duck          Anas rubripes          Game Species
# 4   ALBANY        American Crow  Corvus brachyrhynchos          Game Species
# 5   ALBANY        American Crow  Corvus brachyrhynchos          Game Species
# 6   ALBANY        American Crow  Corvus brachyrhynchos          Game Species
# 7   ALBANY        American Crow  Corvus brachyrhynchos          Game Species
# 8   ALBANY        American Crow  Corvus brachyrhynchos          Game Species
# 9   ALBANY        American Crow  Corvus brachyrhynchos          Game Species
# 10  ALBANY        American Crow  Corvus brachyrhynchos          Game Species
# 11  ALBANY   American Goldfinch         Spinus tristis             Protected
# 12  ALBANY   American Goldfinch         Spinus tristis             Protected
# 13  ALBANY   American Goldfinch         Spinus tristis             Protected
# 14  ALBANY   American Goldfinch         Spinus tristis             Protected
#
#      Family Name     Family Description  \
# 0             71     TYRANT FLYCATCHERS
# 1     TYRANNIDAE     TYRANT FLYCATCHERS
# 2       ANATIDAE   SWANS, GEESE & DUCKS
# 3       ANATIDAE   SWANS, GEESE & DUCKS
# 4       CORVIDAE  JAYS, MAGPIES & CROWS
# 5       CORVIDAE  JAYS, MAGPIES & CROWS
# 6       CORVIDAE  JAYS, MAGPIES & CROWS
# 7       CORVIDAE  JAYS, MAGPIES & CROWS
# 8       CORVIDAE  JAYS, MAGPIES & CROWS
# 9       CORVIDAE  JAYS, MAGPIES & CROWS
# 10      CORVIDAE  JAYS, MAGPIES & CROWS
# 11  FRINGILLIDAE                FINCHES
# 12  FRINGILLIDAE                FINCHES
# 13  FRINGILLIDAE                FINCHES
# 14  FRINGILLIDAE                FINCHES
#
#                                     Breeding Behavior  Month  Day    Year  \
# 0   singing male present on more than one date in ...    NaN  NaN  1985.0
# 1   Nest and eggs, bird on nest or egg, or eggshel...    NaN  NaN  1985.0
# 2   Pair observed in suitable habitat in breeding ...    NaN  NaN  1985.0
# 3   Species seen in possible nesting habitat or si...    NaN  NaN  1985.0
# 4   Singing male present on more than one date in ...    NaN  NaN  1985.0
# 5   Species seen in possible nesting habitat or si...    NaN  NaN  1985.0
# 6   Species seen in possible nesting habitat or si...    NaN  NaN  1985.0
# 7      Adult(s) with food for young or feeding young.    NaN  NaN  1985.0
# 8                                    Nest with young.    NaN  NaN  1985.0
# 9      Adult(s) with food for young or feeding young.    NaN  NaN  1985.0
# 10                            Recently fledged young.    NaN  NaN  1985.0
# 11     Adult(s) with food for young or feeding young.    NaN  NaN  1985.0
# 12     Adult(s) with food for young or feeding young.    NaN  NaN  1985.0
# 13                                   Used nest found.    NaN  NaN  1985.0
# 14  Pair observed in suitable habitat in breeding ...    NaN  NaN  1985.0
#
#     Temperature  Average UB Student GPA Breeding Status
# 0            59                    2.26        Probable
# 1            78                    2.77       Confirmed
# 2            72                    3.08        Probable
# 3            52                    2.09        Possible
# 4            28                    2.28        Probable
# 5            41                    2.86        Possible
# 6            40                    3.62        Possible
# 7            35                    3.06       Confirmed
# 8            55                    3.11       Confirmed
# 9            74                    3.15       Confirmed
# 10           53                    2.53       Confirmed
# 11           35                    2.31       Confirmed
# 12           22                    3.06       Confirmed
# 13           59                    3.20       Confirmed
# 14           55                    3.19        Probable

# %%
df.describe()
# Out:
#          Fed. Region        Month          Day           Year    Temperature  \
# count  355787.000000  3426.000000  9338.000000  351102.000000  361582.000000
# mean        5.855652    49.772329    49.511994    1964.180056      49.467487
# std         5.836586    28.659289    28.794700     190.069866      17.322758
# min         0.000000     0.000000     0.000000       0.000000      20.000000
# 25%         3.000000    26.000000    25.000000    1982.000000      34.000000
# 50%         6.000000    50.000000    49.000000    1983.000000      49.000000
# 75%         8.000000    74.000000    75.000000    1984.000000      64.000000
# max        99.000000    99.000000    99.000000    1985.000000      79.000000
#
#        Average UB Student GPA
# count           361582.000000
# mean                 2.850668
# std                  0.490552
# min                  2.000000
# 25%                  2.430000
# 50%                  2.850000
# 75%                  3.280000
# max                  3.700000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361582 entries, 0 to 361581
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Fed. Region             355787 non-null  float64
#  1   Block ID                358864 non-null  object
#  2   Map Link                356865 non-null  object
#  3   County                  350980 non-null  object
#  4   Common Name             351052 non-null  object
#  5   Scientific Name         354097 non-null  object
#  6   NYS Protection Status   353112 non-null  object
#  7   Family Name             359126 non-null  object
#  8   Family Description      356849 non-null  object
#  9   Breeding Behavior       356399 non-null  object
#  10  Month                   3426 non-null    float64
#  11  Day                     9338 non-null    float64
#  12  Year                    351102 non-null  float64
#  13  Temperature             361582 non-null  int64
#  14  Average UB Student GPA  361582 non-null  float64
#  15  Breeding Status         361582 non-null  object
# dtypes: float64(5), int64(1), object(10)
# memory usage: 44.1+ MB
# None

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['Block ID', 'Map Link', 'County', 'Common Name', 'Scientific Name',
#        'NYS Protection Status', 'Family Name', 'Family Description',
#        'Breeding Behavior', 'Breeding Status'],
#       dtype='object')

# %%
df.select_dtypes(include=['int64','float64']).columns
# Out:
# Index(['Fed. Region', 'Month', 'Day', 'Year', 'Temperature',
#        'Average UB Student GPA'],
#       dtype='object')

# %%
cat = len(df.select_dtypes(include=['object']).columns)
num = len(df.select_dtypes(include=['int64','float64']).columns)
print('Total Features:', cat+num," = ",cat, 'categorical', '+',
      num, 'numerical')
# Out:
# Total Features: 16  =  10 categorical + 6 numerical

# %%
print("Null Values in each column")
print(df.isnull().sum())  
# since month and day are nearly empty , we can drop those columns
df = df.drop(columns=['Month','Day'],axis=1)

# dropping column - Map Link , Average UB Student GPA as it does not impute any relation to prediction
df = df.drop(columns=['Map Link','Average UB Student GPA'],axis = 1)
# Out:
# Null Values in each column
# Fed. Region                 5795
# Block ID                    2718
# Map Link                    4717
# County                     10602
# Common Name                10530
# Scientific Name             7485
# NYS Protection Status       8470
# Family Name                 2456
# Family Description          4733
# Breeding Behavior           5183
# Month                     358156
# Day                       352244
# Year                       10480
# Temperature                    0
# Average UB Student GPA         0
# Breeding Status                0
# dtype: int64

# %%
# finding distinct data and correcting mismatched data
print("Unique values in each column- \n",df.nunique())
# Out:
# Unique values in each column-
#  Fed. Region               100
# Block ID                 8365
# County                    224
# Common Name               727
# Scientific Name           713
# NYS Protection Status     118
# Family Name               189
# Family Description        193
# Breeding Behavior         146
# Year                      106
# Temperature                60
# Breeding Status             3
# dtype: int64

# %%
print("Unique Values and their count\n")
for c in df.columns:
    print(df[c].value_counts(),end="\n")
# Out:
# Unique Values and their count
#
# Fed. Region
# 8.0     48078
# 7.0     41295
# 4.0     40067
# 1.0     38963
# 5.0     38658
#         ...
# 92.0       24
# 67.0       24
# 91.0       24
# 46.0       22
# 47.0       21
# Name: count, Length: 100, dtype: int64
# Block ID
# 3768A    137
# 4372C    120
# 2972A    119
# 3275C    117
# 2472D    115
#         ...
# 2469b      1
# 2271d      1
# 2266b      1
# 2469a      1
# 3071a      1
# Name: count, Length: 8365, dtype: int64
# County
# ST LAWRENCE    18242
# ESSEX          11450
# FRANKLIN       11079
# HAMILTON       10820
# DELAWARE       10482
#                ...
# queens            14
# richmond          11
# bronx              6
# new york           1
# kings              1
# Name: count, Length: 224, dtype: int64
# Common Name
# Song Sparrow              4847
# American Robin            4824
# Black-capped Chickadee    4811
# Common Yellowthroat       4802
# Blue Jay                  4778
#                           ...
# LAUGHING GULL                1
# american oystercatcher       1
# clapper rail                 1
# mute swan                    1
# Dickcissel                   1
# Name: count, Length: 727, dtype: int64
# Scientific Name
# Turdus migratorius        4848
# Melospiza melodia         4848
# Poecile atricapillus      4825
# Geothlypis trichas        4811
# Cyanocitta cristata       4800
#                           ...
# chordeiles minor             1
# FALCO PEREGRINUS             1
# Laterallus jamaicensis       1
# ammodramus henslowii         1
# ANAS CRECCA                  1
# Name: count, Length: 713, dtype: int64
# NYS Protection Status
# Protected                    291782
# Game Species                  23124
# Unprotected                   11817
# Protected-Special Concern      9052
# PROTECTED                      2637
#                               ...
# protected-special concern        62
# threatened                       18
# THREATENED                       18
# endangered                        2
# ENDANGERED                        1
# Name: count, Length: 118, dtype: int64
# Family Name
# PARULIDAE        44503
# EMBERIZIDAE      29775
# TYRANNIDAE       25452
# ICTERIDAE        25392
# PICIDAE          19190
#                  ...
# gaviidae             3
# sylviidae            3
# alaudidae            3
# laridae              1
# podicipedidae        1
# Name: count, Length: 189, dtype: int64
# Family Description
# WOOD WARBLERS                           43797
# TOWHEES, BUNTINGS, SPARROWS & ALLIES    29312
# TYRANT FLYCATCHERS                      25148
# BLACKBIRDS                              25021
# WOODPECKERS & ALLIES                    18895
#                                         ...
# grebes                                      2
# barn owls                                   2
# new world quail                             2
# oystercatchers                              1
# cormorants                                  1
# Name: count, Length: 193, dtype: int64
# Breeding Behavior
# Species seen in possible nesting habitat or singing male(s) present in breeding season.    102743
# Recently fledged young.                                                                     46779
# Adult(s) with food for young or feeding young.                                              42430
# Singing male present on more than one date in the same place.                               35523
# Bird (or pair) apparently holding teritory.                                                 31194
#                                                                                             ...
# nest building or excavation of a nest hole.                                                    27
# visiting probable nest site.                                                                   25
# VISITING PROBABLE NEST SITE.                                                                   19
# ADULT CARRYING FECAL SAC.                                                                      11
# adult carrying fecal sac.                                                                       5
# Name: count, Length: 146, dtype: int64
# Year
# 1984.0    95626
# 1983.0    78355
# 1985.0    59339
# 1982.0    51321
# 1981.0    38896
#           ...
# 79.0         23
# 90.0         23
# 96.0         22
# 89.0         20
# 6.0          18
# Name: count, Length: 106, dtype: int64
# Temperature
# 30    6233
# 25    6202
# 52    6179
# 22    6163
# 54    6138
# 62    6135
# 74    6128
# 20    6115
# 49    6111
# 55    6102
# 27    6091
# 58    6088
# 44    6085
# 56    6085
# 69    6076
# 66    6076
# 34    6071
# 78    6052
# 35    6050
# 28    6049
# 67    6037
# 36    6035
# 39    6030
# 73    6026
# 43    6024
# 40    6022
# 47    6022
# 60    6018
# 75    6018
# 23    6015
# 24    6014
# 79    6014
# 50    6013
# 57    6009
# 65    6008
# 38    6004
# 68    5998
# 63    5998
# 64    5994
# 32    5989
# 61    5986
# 29    5984
# 42    5982
# 53    5979
# 70    5974
# 21    5974
# 51    5960
# 26    5959
# 46    5958
# 59    5955
# 33    5952
# 72    5952
# 41    5951
# 71    5949
# 48    5940
# 31    5937
# 77    5936
# 45    5926
# 37    5907
# 76    5904
# Name: count, dtype: int64
# Breeding Status
# Confirmed    142635
# Possible     110025
# Probable     108922
# Name: count, dtype: int64

# %%
# we replace missing values with mean - where data type is numerical and mode - where data type is categorical
for i in df.select_dtypes(include=['object']).columns:
        mode_value = df[i].mode()[0]
        df[i].fillna(mode_value,inplace=True)

for i in df.select_dtypes(include=['int64','float64']).columns:
        mean_value = df[i].mean()
        df[i].fillna(math.ceil(mean_value),inplace=True)

print(df.isnull().sum())
# Out:
# Fed. Region              0
# Block ID                 0
# County                   0
# Common Name              0
# Scientific Name          0
# NYS Protection Status    0
# Family Name              0
# Family Description       0
# Breeding Behavior        0
# Year                     0
# Temperature              0
# Breeding Status          0
# dtype: int64

# %%
# Checking for outliers in Years and Fed. Region

print("Count where years < 1900: ",df[df['Year']<1900]['Year'].count())
print("Count where Fed. Region > 15: ",df[df['Fed. Region']>15]['Fed. Region'].count())
# Out:
# Count where years < 1900:  3423
# Count where Fed. Region > 15:  2890

# %%
# since number of rows are greater we replace them with mean

yearMean = df[df['Year']>=1900]['Year'].mean()
df.loc[df['Year']<1900,'Year'] = math.ceil(yearMean)

regionMean = df[df['Fed. Region']<=15]['Fed. Region'].mean()
df.loc[df['Fed. Region']>15,'Fed. Region'] = math.ceil(regionMean)

# %%
# checking for numeric values in string values

for c in df.select_dtypes(include=['object']):
    numericValues = df[c].str.isnumeric()
    print(c,"-",numericValues.sum())

#  since the data count is high , we are replacing it with mode
for c in df.select_dtypes(include=['object']):
    numericValues = df[c].str.isnumeric()
    modeValue = df[c].mode()[0] #getting first index
    df.loc[numericValues,c]=modeValue
    
    # setting row values to lowercase to make all string unique
    df[c]=df[c].str.lower()
# Out:
# Block ID - 6502
# County - 3452
# Common Name - 3454
# Scientific Name - 6539
# NYS Protection Status - 9259
# Family Name - 9183
# Family Description - 9205
# Breeding Behavior - 6526
# Breeding Status - 0

# %%
print("Unique values in each column after processing data\n",df.nunique())
# Out:
# Unique values in each column after processing data
#  Fed. Region                16
# Block ID                 5323
# County                     62
# Common Name               245
# Scientific Name           245
# NYS Protection Status       6
# Family Name                48
# Family Description         48
# Breeding Behavior          16
# Year                        7
# Temperature                60
# Breeding Status             3
# dtype: int64

# %%
# plotting graph to understand the data
for c in df.select_dtypes(include=['int64','float64']).columns:
    plt.figure(figsize=(7, 4))
    sns.boxplot(x=df[c])  
    plt.show()

# %%
columns = ['Fed. Region','Year','County','Family Name','Breeding Behavior']
for c in columns:
    ct_count = df[c].value_counts()
    plt.figure(figsize=(5,5))
    plt.bar(ct_count.index,ct_count.values , color = 'purple')
    plt.title(f"Bar Plot for {c}")
    plt.xlabel(f"Distinct {c}")
    plt.ylabel("Count")
    plt.xticks(rotation = 50, fontsize=5)
    plt.show()

# %%
for col in list(set(df.columns) - set(['Breeding Status','Block ID','Common Name','Scientific Name','Temperature','Breeding Behavior'])):

    unique_values = df['Breeding Status'].unique()

    fig,axs=plt.subplots(1,len(unique_values),figsize=(8,5))
    for i, value in enumerate(unique_values):
        sub = df[df['Breeding Status']==value]
        sns.countplot(data=sub, x='Breeding Status', hue=col, palette='viridis',ax=axs[i])
        axs[i].legend_.remove()
    fig.suptitle(f'Count of {"Breeding Status"} by {col}')
    plt.tight_layout()
    plt.show()

# %%
g = sns.FacetGrid(df, col="Breeding Status", col_wrap=3, height=4)
g.map(sns.histplot, 'Year') 
plt.show()

# %%
# since certains columns have lot of distinct values , it is not ideal to use one-hot encoding as it would make the model complex with lot of columns and create a over-fitted model
# hence we use frequency-encdoing
for col in ["Block ID","Common Name","Family Description","Scientific Name","Family Name","County"]:
    frequency = df[col].value_counts()
    df[col] = df[col].map(frequency)

# normalizing the data 
for col in ["Block ID","Common Name","Family Description","Scientific Name","Family Name","County","Year","Temperature","Fed. Region"]:
    xMax = df[col].max(axis=0)
    xMin = df[col].min(axis=0)
    df[col]=df[col].apply(lambda x: (x-xMin)/(xMax-xMin))
    
# for others we can use one-hot encoding
for col in ["Breeding Behavior"]:
    df = pd.get_dummies(df, columns=[col],drop_first=True) 

# for NYS Protection Status we can do label encoding
uniqueCategory = df['NYS Protection Status'].unique()
categoryIndex = {category:id for id ,category in enumerate(uniqueCategory)}
df['NYS Protection Status Encoded'] = df['NYS Protection Status'].map(categoryIndex)
df = df.drop("NYS Protection Status",axis = 1)

# %%
numeric_df = df.select_dtypes(include=['float64','int64','bool'])
# truncating column name to 10 

temp_columns = [col[:10] for col in numeric_df.columns]
numeric_df.columns = temp_columns
correlation_matrix = numeric_df.corr()


plt.figure(figsize=(16, 16))

sns.heatmap(correlation_matrix, 
            annot=True,        
            cmap='cool',  
            vmin=0, vmax=1,  
            linewidths=0.5,  
            square=True,
            fmt='.3f')    

plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# Report -
#
# Methods For Data preprocessing -
# * First I took overview of the dataset
# * Understood the data given
# * After analysing the features , I dropped columns which are irrelevant for the prediction
# * I replaced the empty values with mean and mode wherever applicable
# * I created box plot to look for any outliers and later removed it.
# * I started encoding the categorical features using Lablel ,One Hot and frequency encoding
#
# Overview of DataSet
# * Domain - Birds Breeding Based on location
# * Number of samples - 361582
# * Features - 15
#
# Key Statistics
# * Mean -
#     * Fed. Region -5.855652
#     * Month	- 49.772329
#     * Day	- 49.511994
#     * Year	- 1964.180056
#     * Temperature	- 49.467487
#     * Average UB Student GPA  - 2.850668
#
# * Standard Deviation -
#     * Fed. Region	- 5.836586
#     * Month	- 28.659289
#     * Day	- 28.794700
#     * Year	- 190.069866
#     * Temperature	- 17.322758
#     * Average UB Student GPA  - 0.490552
# * Missing Values For each feature-
#     * Fed. Region -                5795
#     * Block ID     -               2718
#     * Map Link      -              4717
#     * County         -            10602
#     * Common Name     -           10530
#     * Scientific Name  -           7485
#     * NYS Protection Status -      8470
#     * Family Name            -     2456
#     * Family Description      -    4733
#     * Breeding Behavior       -    5183
#     * Month                 -    358156
#     * Day                  -     352244
#     * Year                 -      10480

# %% [markdown]
# Part 2 - Logistic Regression using Gradient Descent

# %%
# setting  X_train, y_train, X_test, y_test

df['Breeding Status'] = df['Breeding Status'].apply(lambda x: 1 if x == 'confirmed' else 0)


features = list(set(df.columns) - set(['Breeding Status']))

X = df[features].values
y = df['Breeding Status'].values

indices = np.arange(X.shape[0])
np.random.shuffle(indices)

X = X[indices].astype(float)
y = y[indices].astype(float)

split_ratio = 0.8 
split_index = int(len(X) * split_ratio)

X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (289265, 25) (72317, 25) (289265,) (72317,)

# %%
hyperparamters = [[0.03,10000],[0.2,20000],[0.4,30000]] # learning_rate , iterations

for i in hyperparamters:
    j = 1
    model = LogitRegression(learning_rate=i[0] ,iterations=i[1])
    loss = model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    print(f"Iteration{j}: Accuracy: ",np.mean(predictions == y_test))

    j+=1

    plt.plot(loss)
    plt.xlabel("Iterations")
    plt.ylabel("Cost")
    plt.title(f"Learning Rate {i[0]}")
    plt.show()
# Out:
# 100%|██████████| 10000/10000 [04:55<00:00, 33.86it/s]
# Iteration1: Accuracy:  0.9853284843121258
# 100%|██████████| 20000/20000 [10:21<00:00, 32.17it/s]
# Iteration1: Accuracy:  0.9866836290222216
# 100%|██████████| 30000/30000 [11:39<00:00, 42.86it/s]
# Iteration1: Accuracy:  0.9868910491309097

# %%
# df.to_excel('updated_file.xlsx', index=False)
